# %% [markdown]
# <a href="https://colab.research.google.com/github/munimshahriar1/abnormal-ecg-classification/blob/main/classifier_mitbih_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Find details about the database at:
# **https://www.kaggle.com/datasets/protobioengineering/mit-bih-arrhythmia-database-modern-2023?resource=download**

# %%
url = 'https://raw.githubusercontent.com/munimshahriar1/abnormal-ecg-classification/main/208.csv'
ecg208 = pd.read_csv(url)

# %%
ecg208
# Out:
#         Unnamed: 0       time_ms   MLII     V1
# 0                0  0.000000e+00 -0.105  0.190
# 1                1  2.777778e+00 -0.105  0.190
# 2                2  5.555556e+00 -0.105  0.190
# 3                3  8.333333e+00 -0.105  0.190
# 4                4  1.111111e+01 -0.105  0.190
# ...            ...           ...    ...    ...
# 649995      649995  1.805542e+06 -0.225 -0.095
# 649996      649996  1.805544e+06 -0.195 -0.105
# 649997      649997  1.805547e+06 -0.170 -0.100
# 649998      649998  1.805550e+06 -0.160 -0.110
# 649999      649999  1.805553e+06  0.000  0.000
#
# [650000 rows x 4 columns]

# %%
ecg208.head()
# Out:
#    Unnamed: 0    time_ms   MLII    V1
# 0           0   0.000000 -0.105  0.19
# 1           1   2.777778 -0.105  0.19
# 2           2   5.555556 -0.105  0.19
# 3           3   8.333333 -0.105  0.19
# 4           4  11.111111 -0.105  0.19

# %%
ecg208["MLII"].plot()
plt.title("30-minute EKG of Patient 208")
# Out:
# Text(0.5, 1.0, '30-minute EKG of Patient 208')

# %%
ecg208[0:1800]["MLII"].plot()
plt.title("First 4 heartbeats of patient 100's EKG")
# Out:
# Text(0.5, 1.0, "First 4 heartbeats of patient 100's EKG")
